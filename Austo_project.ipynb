# %% [markdown]
# <a href="https://colab.research.google.com/github/olapeterola/pyt/blob/main/Austo_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Python Foundations: Austo

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context
#
# In the 21st century, cars are an important mode of transportation that provides us the opportunity for personal control and autonomy. In day-to-day life, people use cars for commuting to work, shopping, visiting family and friends, etc. Research shows that more than 76% of people prevent themselves from traveling somewhere if they don't have a car. Most people tend to buy different types of cars based on their day-to-day necessities and preferences. So, it is essential for automobile companies to analyze the preference of their customers before launching a car model into the market. Austo, a UK-based automobile company aspires to grow its business into the US market after successfully establishing its footprints in the European market.
#
# In order to be familiar with the types of cars preferred by the customers and factors influencing the car purchase behavior in the US market, Austo has contracted a consulting firm. Based on various market surveys, the consulting firm has created a dataset of 3 major types of cars that are extensively used across the US market. They have collected various details of the car owners which can be analyzed to understand the automobile market of the US.

# %% [markdown]
# ### Objective
#
# Austo's management team wants to understand the demand of the buyers and trends in the US market. They want to build customer profiles based on the analysis to identify new purchase opportunities so that they can manipulate the business strategy and production to meet certain demand levels. Further, the analysis will be a good way for management to understand the dynamics of a new market. Suppose you are a Data Scientist working at the consulting firm that has been contracted by Austo. You are given the task to create buyer's profiles for different types of cars with the available data as well as a set of recommendations for Austo. Perform the data analysis to generate useful insights that will help the automobile company to grow its business.
#
# ### Data Description
#
# austo_automobile.csv: The dataset contains buyer's data corresponding to different types of products(cars).
#
# ### Data Dictionary
#
# * Age: Age of the customer
# * Gender: Gender of the customer
# * Profession: Indicates whether the customer is a salaried or business person
# * Marital_status: Marital status of the customer
# * Education: Refers to the highest level of education completed by the customer
# * No_of_dependents: Number of dependents(partner/children/spouse) of the customer
# * Personal_loan: Indicates whether the customer availed a personal loan or not
# * House_loan: Indicates whether the customer availed house loan or not
# * Partner_working: Indicates whether the customer's partner is working or not
# * Salary: Annual Salary of the customer
# * Partner_salary: Annual Salary of the customer's partner
# * Total_salary: Annual household income (Salary + Partner_salary) of the customer's family
# * Price: Price of the car
# * Make: Car type (Hatchback/Sedan/SUV)

# %% [markdown]
# ### **Please read the instructions carefully before starting the project.**
# This is a commented Jupyter IPython Notebook file in which all the instructions and tasks to be performed are mentioned. Read along carefully to complete the project.
# * Blanks '_______' are provided in the notebook that
# needs to be filled with an appropriate code to get the correct result. Please replace the blank with the right code snippet. With every '_______' blank, there is a comment that briefly describes what needs to be filled in the blank space.
# * Identify the task to be performed correctly, and only then proceed to write the required code.
# * Fill the code wherever asked by the commented lines like "# write your code here" or "# complete the code". Running incomplete code may throw an error.
# * Please run the codes in a sequential manner from the beginning to avoid any unnecessary errors.
# * You can the results/observations derived from the analysis here and use them to create your final presentation.

# %% [markdown]
# ## Importing necessary libraries

# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing the dataset

# %%
# uncomment and run the following lines for Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read the data
df = pd.read_csv('/content/drive/MyDrive/DA/python_course_2/project2/austo_automobile.csv') ## Complete the code to read the data
# returns the first 5 rows
df.head()
# Out:
#    Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   24   Male   Salaried        Married  Post Graduate                 4
# 1   28   Male   Salaried        Married  Post Graduate                 3
# 2   23   Male   Salaried        Married       Graduate                 4
# 3   26   Male   Business        Married  Post Graduate                 4
# 4   28   Male   Business        Married  Post Graduate                 4
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No        Yes             Yes   52000           25000
# 1            No        Yes              No   68000               0
# 2           Yes        Yes              No   31000               0
# 3           Yes        Yes             Yes   66000           35000
# 4           Yes         No              No   64000               0
#
#    Total_salary  Price       Make
# 0         77000  18000  Hatchback
# 1         68000  18000  Hatchback
# ...

# %% [markdown]
# ## Data Overview

# %% [markdown]
# ### Question 1: How many rows and columns are present in the data?

# %%
# Check the shape of the dataset
df.shape ## Fill in the blank
print("There are", df.shape[0], "rows and", df.shape[1], "columns in the given data")
# Out:
# There are 1581 rows and 14 columns in the given data

# %% [markdown]
# ### Question 2: What are the datatypes of the different columns in the dataset?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1581 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1581 non-null   int64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: int64(6), object(8)
# memory usage: 173.0+ KB

# %% [markdown]
# ### Question 3: Check the statistical summary of the data. List all the observations for each column?

# %%
# Get the summary statistics of the numerical data
df.describe(include='all').T## Complete the Code to print the statitical summary of the data (Hint - you have seen this in the case studies before)
# Out:
#                    count unique            top  freq          mean  \
# Age               1581.0    NaN            NaN   NaN     32.211259
# Gender              1581      2           Male  1252           NaN
# Profession          1581      2       Salaried   896           NaN
# Marital_status      1581      2        Married  1443           NaN
# Education           1581      2  Post Graduate   985           NaN
# No_of_Dependents  1581.0    NaN            NaN   NaN      2.457938
# Personal_loan       1581      2            Yes   792           NaN
# House_loan          1581      2             No  1054           NaN
# Partner_working     1581      2            Yes   868           NaN
# Salary            1581.0    NaN            NaN   NaN  59732.447818
# Partner_salary    1581.0    NaN            NaN   NaN  19720.430108
# Total_salary      1581.0    NaN            NaN   NaN  79452.877925
# Price             1581.0    NaN            NaN   NaN   35597.72296
# ...

# %% [markdown]
# The age of customers ranges from 25 to 60 years, their mean age is around 32.
# There are 1252 males customers.
# There are more customers who earn salaries compared to customers who run a business
# Most of the customers are married, 1443 customers are married
# There are 985 customers with postgraduate degrees
# The number of dependants of customers ranges from 0 to 4
# There are 792 customers with personal loan
# There are 1054 customers with house loans
# Most customers have partners who work
# The salary of customers range from 30000 to 90000 with mean around 59732.44
# Customers have partners whose salaries range between 0 to 80000
# Customers total salary range from 61000	to	158000
# Price of car range from 18000 to	70000
# There are three make/car types, customers buy Hatchback most

# %% [markdown]
# #### Question 4: Are there any missing values in the data? If yes, treat them using an appropriate method.

# %%
# Checking for missing values in the data
df.isnull().sum()  #Write the appropriate function to print the sum of null values for each column
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %% [markdown]
# ### Question 5: How many cars are there of type SUV?

# %%
#df['______'].value_counts() ## Complete the Code to list the counts of SUV cars
df.Make.value_counts()
# Out:
# Make
# Hatchback    884
# Sedan        460
# SUV          237
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### **Question 6:** Explore all the variables and provide observations on the distributions. (Generally, histograms, boxplots, countplots, etc. are used for univariate exploration.)

# %% [markdown]
# ##### Observations on Age

# %%
## Histogram boxplot for the Age
sns.histplot(data=df,x='Age')
plt.show()
sns.boxplot(data=df,x='Age')
plt.show()

# %% [markdown]
# ##### Gender

# %%
# Check Gender type
df['Gender'].unique() ## Complete the code to find out unique Gender type
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
sns.countplot(data=df,x='Gender') ## Complete the code to plot 'Gender' column
plt.show()

# %% [markdown]
# ##### Profession

# %%
# Check Profession type
df['Profession'].unique() ## Complete the code to find out unique Profession type
# Out:
# array(['Salaried', 'Business'], dtype=object)

# %%
sns.countplot(data=df,x='Profession') ## Complete the code to plot  'Profession' column
plt.show()

# %% [markdown]
# ##### Marital status

# %%
# Check the unique values
df['Marital_status'].unique() ## Complete the code to find out unique Marital_status type
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
sns.countplot(data=df,x='Marital_status') ## Complete the code to plot 'Marital_status' column
plt.show()

# %% [markdown]
# ##### Education

# %%
# Check Education type
df['Education'].unique() ## Complete the code to find out unique Education type
# Out:
# array(['Post Graduate', 'Graduate'], dtype=object)

# %%
sns.countplot(data=df,x='Education') ## Complete the code to plot 'Education' column
plt.show()

# %% [markdown]
# ##### Number of dependents

# %%
# Check the unique values
df['No_of_Dependents'].unique() ## Complete the code to find out unique No_of_Dependents type
# Out:
# array([4, 3, 0, 2, 1])

# %%
sns.countplot(data=df,x='No_of_Dependents') ## Complete the code to plot for 'No_of_Dependents' column
plt.show()

# %% [markdown]
# ##### Personal loan

# %%
# Check the unique values
df['Personal_loan'].unique() ## Complete the code to find out unique Personal_loan type
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sns.countplot(data=df,x='Personal_loan') ## Complete the code to plot 'day_of_the_week' column
plt.show()

# %% [markdown]
# ##### House loan

# %%
# # Check the unique values
df['House_loan'].unique() ## Complete the code to check unique values for the 'House_loan' column
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
sns.countplot(data=df,x='House_loan') ## Complete the code to plot 'House_loan' column
plt.show()

# %% [markdown]
# ##### Working status of customer's partner

# %%
# # Check the unique values
df['Partner_working'].unique() ## Complete the code to check unique values for the 'Partner_working' column
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
sns.countplot(data=df,x='Partner_working') ## Complete the code to plot 'Partner_working' column
# Out:
# <Axes: xlabel='Partner_working', ylabel='count'>

# %% [markdown]
# ##### Observations on Salary

# %%
## Complete the code to plot histogram and boxplot for 'Salary' column
## Histogram boxplot for the Age
sns.histplot(data=df,x='Salary')
plt.show()
sns.boxplot(data=df,x='Salary')
plt.show()

# %% [markdown]
# ##### Observations on Partner's salary

# %%
## Complete the code to plot histogram and boxplot for 'Partner's column
sns.histplot(data=df,x='Partner_salary')
plt.show()
sns.boxplot(data=df,x='Partner_salary')
plt.show()

# %% [markdown]
# ##### Observations on Total salary

# %%
## Complete the code to plot histogram and boxplot for 'Total_salary' column
sns.histplot(data=df,x='Total_salary')
plt.show()
sns.boxplot(data=df,x='Total_salary')
plt.show()

# %% [markdown]
# ##### Observations on Price

# %%
## Complete the code to plot histogram and boxplot for 'Price' column
sns.histplot(data=df,x='Price')
plt.show()
sns.boxplot(data=df,x='Price')
plt.show()

# %% [markdown]
# ##### Make

# %%
# # Check the unique values
df['Make'].unique() ## Complete the code to check unique values for the 'Make' column
# Out:
# array(['Hatchback', 'SUV', 'Sedan'], dtype=object)

# %%
sns.countplot(data=df,x='Make') ## Complete the code to plot for 'Make' column
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %% [markdown]
# #### Question 7: How many cars are of make Hatchback and priced above 25000. State your observations?

# %%
# Get the cars whose make is hatchback.
df_hatchback = df[df['Make'] == 'Hatchback']

# Get the cars which are priced above 25000.
df_hatchback[df['Price']>25000].shape[0]
# Out:
# 444

# %% [markdown]
# #### Question 8: How many owners have bought cars that were priced higher than their salary. How many of them have taken personal loan?

# %%
# Get the number of owners who have taken cars pricing higher than their salary
df_pricing = df[df['Price'] > df['Salary']]

print('Number of owners who have purchased cars pricing higher than their salary:',df_pricing.shape[0])

# Get the number of owners who  have taken cars pricing higher than their salary and have taken personal loan.
df_personal_loan = df_pricing[df['Personal_loan'] == 'Yes']
print('Number of owners who have taken personal loan and have cars pricing higher than their salary:', df_personal_loan.shape[0])
# Out:
# Number of owners who have purchased cars pricing higher than their salary: 96
# Number of owners who have taken personal loan and have cars pricing higher than their salary: 44

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# #### Question 9: Perform bivariate/multivariate analysis to explore relationships between the important variables in the dataset.

# %%
# Plot the heatmap to find the correlation between numerical variables
col_list = ['Age', 'No_of_Dependents', 'Salary', 'Partner_salary', 'Total_salary', 'Price']
plt.figure(figsize=(15, 7))
sns.heatmap(df[col_list].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %%
# pairplot to show the relationship between numerical variables set hue to Make
sns.pairplot(data = df, hue = "Make")
plt.show()

# %% [markdown]
# ##### Make vs Age

# %%
# boxplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='Make', y='Age')  ## Complete the code to visualize the relationship between Make and Age using boxplot
plt.show()

# %% [markdown]
# ##### Make vs Price

# %%
# boxplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='Make', y='Price')  ## Complete the code to visualize the relationship between make and price using boxplot
plt.show()

# %% [markdown]
# ##### Make vs Salary

# %%
# boxplot to show relationship between two variables
plt.figure(figsize=(15,7))
#sns.boxplot('df["Make"],df["Salary"]')
sns.boxplot(data=df, x='Make', y='Salary')   ## Complete the code to visualize the relationship between make and salary using boxplot
plt.show()

# %% [markdown]
# ##### Make vs Education

# %%
# countplot to show relationship between two variables
plt.figure(figsize=(15,7))
#sns.countplot(df["Make"],hue=df["Education"])
sns.countplot(x="Make", hue="Education", data=df) ## Complete the code to visualize the relationship between make and education using countplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ##### Make vs No_of_Dependents

# %%
# countplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.countplot(x="Make", hue="No_of_Dependents", data=df)  ## Complete the code to visualize the relationship between make and no of dependents using countplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ##### Make vs Profession

# %%
# countplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.countplot(x="Make", hue="Profession", data=df)  ## Complete the code to visualize the relationship between make and profession using countplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ##### Make vs Personal loan

# %%
# countplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.countplot(x="Make", hue="Personal_loan", data=df)  ## Complete the code to visualize the relationship between make and personal loan using countplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ##### Make vs House loan

# %%
# countplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.countplot(x="Make", hue="House_loan", data=df)  ## Complete the code to visualize the relationship between make and House Loan using countplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ##### Grouping data w.r.t to car types to build customer profiles

# %% [markdown]
# ###### Grouping data w.r.t to Hatchback

# %%
df[df["Make"]=="Hatchback"].describe(include="all") # Group data w.r.t to Hatchback to build customer profiles
# Out:
#                Age Gender Profession Marital_status      Education  \
# count   884.000000    884        884            884            884
# unique         NaN      2          2              2              2
# top            NaN   Male   Business        Married  Post Graduate
# freq           NaN    869        443            800            552
# mean     25.874434    NaN        NaN            NaN            NaN
# std       2.520373    NaN        NaN            NaN            NaN
# min      22.000000    NaN        NaN            NaN            NaN
# 25%      24.000000    NaN        NaN            NaN            NaN
# 50%      26.000000    NaN        NaN            NaN            NaN
# 75%      28.000000    NaN        NaN            NaN            NaN
# max      30.000000    NaN        NaN            NaN            NaN
#
#         No_of_Dependents Personal_loan House_loan Partner_working  \
# count         884.000000           884        884             884
# ...

# %% [markdown]
# ###### Grouping data w.r.t to Sedan

# %%
df[df["Make"]=="Sedan"].describe(include="all") # Group data w.r.t to Sedan to build customer profiles
# Out:
#                Age Gender Profession Marital_status      Education  \
# count   460.000000    460        460            460            460
# unique         NaN      2          2              2              2
# top            NaN   Male   Salaried        Married  Post Graduate
# freq           NaN    259        289            422            289
# mean     36.458696    NaN        NaN            NaN            NaN
# std       5.093080    NaN        NaN            NaN            NaN
# min      28.000000    NaN        NaN            NaN            NaN
# 25%      32.000000    NaN        NaN            NaN            NaN
# 50%      36.000000    NaN        NaN            NaN            NaN
# 75%      41.000000    NaN        NaN            NaN            NaN
# max      45.000000    NaN        NaN            NaN            NaN
#
#         No_of_Dependents Personal_loan House_loan Partner_working  \
# count         460.000000           460        460             460
# ...

# %% [markdown]
# ###### Grouping data w.r.t to SUV

# %%
df[df["Make"]=="SUV"].describe(include="all") # Group data w.r.t to SUV to build customer profiles
# Out:
#                Age Gender Profession Marital_status      Education  \
# count   237.000000    237        237            237            237
# unique         NaN      2          2              2              2
# top            NaN   Male   Salaried        Married  Post Graduate
# freq           NaN    124        166            221            144
# mean     47.603376    NaN        NaN            NaN            NaN
# std       7.733023    NaN        NaN            NaN            NaN
# min      35.000000    NaN        NaN            NaN            NaN
# 25%      41.000000    NaN        NaN            NaN            NaN
# 50%      47.000000    NaN        NaN            NaN            NaN
# 75%      54.000000    NaN        NaN            NaN            NaN
# max      60.000000    NaN        NaN            NaN            NaN
#
#         No_of_Dependents Personal_loan House_loan Partner_working  \
# count         237.000000           237        237             237
# ...

# %% [markdown]
# ##### Customer Segmentation

# %% [markdown]
# ###### Profession vs Price

# %%
# boxplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='Price',hue='Profession')  ## Complete the code to visualize the relationship between profession and price using boxplot
plt.show()

# %% [markdown]
# ###### Education vs Price vs Make

# %%
# boxplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='Price',y='Make',  hue='Education')  ## Complete the code to visualize the relationship between Education, Price and Make using boxplot
plt.show()

# %% [markdown]
# ###### Education vs Price

# %%
# boxplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='Price', hue='Education') ## Complete the code to visualize the relationship between Education and Price  using boxplot
plt.show()

# %% [markdown]
# ###### Profession vs Price vs Education

# %%
# boxplot to show relationship between three variables
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='Price',y='Profession',  hue='Education')  ## Complete the code to visualize the relationship between Profession, Price and Education using boxplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ###### Gender vs Price vs Education

# %%
# boxplot to show relationship between three variables
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x='Price',y='Gender',  hue='Education') ## Complete the code to visualize the relationship between Profession, Price and Education using boxplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ###### Number of Dependents vs Price vs Profession

# %%
# pointplot to show relationship between three variables
plt.figure(figsize=(15,7))
sns.pointplot(data=df, x='No_of_Dependents',y='Price',  hue='Profession', ci=0)  ## Complete the code to visualize the relationship between Number of Dependents, Price and Profession using pointplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ###### Age vs Price vs Make

# %%
# lineplot to show relationship between three variables
plt.figure(figsize=(15,7))
sns.lineplot(data=df, x='Age',y='Price',  hue=df["Make"],ci=0) ## Complete the code to visualize the relationship between Age, Price and Make using pointplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ###### Age vs Price vs House Loan

# %%
# lineplot to show relationship between three variables
plt.figure(figsize=(15,7))
#sns.boxplot(data=df, x='Price',y='Make',  hue='Education')
sns.lineplot(data=df, x='Price',y='Make',hue=df["House_loan"],ci=0)## Complete the code to visualize the relationship between Age, Price and House Loan using pointplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# #### Question 10: For customers who have 3 or fewer dependents, how does the average car price vary by profession?

# %%
df_dependents = df[df['No_of_Dependents'] <= 3] # Get the columns for no of dependents less than or equal to 3
df_profession = df_dependents.groupby(['Profession'])['Price'].mean().sort_values(ascending = False).reset_index()
df_profession
# Out:
#   Profession         Price
# 0   Salaried  37036.175711
# 1   Business  32830.220713

# %% [markdown]
# #### Question 11: For customers who have availed a home loan and a personal loan, how does the price vary by profession?

# %%
# Filter the data for House Loans and Personal Loans
df_PL = df[df['Personal_loan'] == 'Yes']
df_HL = df[df['House_loan'] == 'Yes']

plt.figure(figsize=(15,7))

sns.boxplot(data=df_PL, x='Price', y='Profession')
#sns.boxplot(data=df_HL, x='Price', y='Profession')   ## Complete the code to visualize the relationship between Price and Profession using boxplot
plt.show()

# %% [markdown]
# ## Conclusion and Recommendations

# %% [markdown]
# #### **Question 12:** Write the conclusions and business recommendations derived from the analysis.
